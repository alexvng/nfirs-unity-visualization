# %%
import requests
import json
import csv
import pandas as pd
import urllib.parse
import numpy as np

pd.set_option('display.max_columns', None)       # Show all columns
pd.set_option('display.width', None)

# %%
with open('secrets/gmaps_key', 'r') as f:
    api_key = f.read()

# %%
with open('fires_in_tempe_loc1.csv','r') as f:
    df = pd.read_csv(f)

df = df.iloc[:,1:]
# df['_addr'] = df['_addr'].map(lambda val: urllib.parse.quote(val))
df

responses = pd.read_pickle('api_response.pkl')
# Out:
#                                    _addr  \
# 0       9631 S LA ROSA DR Tempe AZ 85284
# 1        6230 S TAYLOR DR Tempe AZ 85283
# 2    1512 N SCOTTSDALE RD Tempe AZ 85281
# 3         485 W CARMEN ST Tempe AZ 85283
# 4        1245 E LAGUNA DR Tempe AZ 85282
# ..                                   ...
# 249    636 W MANHATTON DR Tempe AZ 85282
# 250      40 E GAMMAGE PKY Tempe AZ 85281
# 251  3141 S MCCLINTOCK DR Tempe AZ 85282
# 252    2425 E APACHE BLVD Tempe AZ 85281
# 253      425 W HERMOSA DR Tempe AZ 85282
#
#                                                  _desc    INC_DATE
# 0    Number of Residential Units: 1.0\nArea of Orig...  2023-01-10
# 1    Number of Residential Units: 1.0\nArea of Orig...  2023-01-10
# 2    Area of Origin: Engine area, running gear, whe...  2023-01-20
# 3    Number of Residential Units: 1.0\nNumber of Bu...  2023-02-01
# 4    Number of Residential Units: 1.0\nArea of Orig...  2023-02-07
# ..                                                 ...         ...
# 249  Area of Origin: Undetermined\nHeat Source: Und...  2023-12-25
# 250  Not Residential Flag: True\nNumber of Building...  2023-12-26
# 251  Number of Residential Units: 0.0\nNumber of Bu...  2023-12-27
# 252  Number of Residential Units: 1.0\nNumber of Bu...  2023-12-30
# 253  Number of Residential Units: 1.0\nLess Than On...  2023-12-31
#
# [254 rows x 3 columns]

# %%
# # responses = []
# # url = 'https://maps.googleapis.com/maps/api/geocode/json'

# # for i,row in df.iterrows():
# #     params = {
# #         'key': api_key,
# #         'outputFormat': 'json',
# #         'address': row['_addr']
# #     }
# #     print(row['_addr'])
# #     response = requests.get(url, params=params)
# #     if response.status_code == 200:
# #         responses.append(response.json())
# #         print(response.json())
# #     else:
# #         print(f"Error {response.status_code}")
# #     # break

# # pd.to_pickle(responses, 'api_response.pkl')

# with open('api_response.json','w') as f:
#     f.write(json.dumps(responses))

# %%
lat = []
lng = []
for r in responses:
    lat.append(r['results'][0]['geometry']['location']['lat'])
    lng.append(r['results'][0]['geometry']['location']['lng'])

# %%
df['lat'] = lat
df['lng'] = lng
df.to_csv('nfirs_cleaned_forunity.csv',index=False)
