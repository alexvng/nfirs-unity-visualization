# %% [markdown]
# # NFIRS data input and processing
#
# This series of 3 Jupyter notebooks consumes a NFIRS Fire/Hazmat data folder (one year, version 5.0 required), and outputs a GeoJSON file with coordinates from Google Maps Geocoding API.
#
# This data is piped to Unity for visualization via Cesium.
#
# ## Part 1: NFIRS raw data intake, cleaning, and address extraction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import csv
import os
import datetime
from collections import defaultdict
import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
out_file_path = '2023_fires_in_tempe_loc1.csv'
folderpath = "./NFIRS_FIRES_2023" # unzip first

# %% [markdown]
# `codelookup.txt` is a lookup table that matches codes to their text descriptor. Important later

# %%
with open(f'{folderpath}/codelookup.txt', 'r') as f:
    lookup_table = pd.read_csv(f, sep="^")

lookup_table.head()
# Out:
#     fieldid code_value           code_descr
# 0  ACT_TAK1        NaN      ACTIONS TAKEN 1
# 1  ACT_TAK1         00  Action taken, other
# 2  ACT_TAK1          1                 Fire
# 3  ACT_TAK1         10          Fire, other
# 4  ACT_TAK1         11           Extinguish

# %% [markdown]
# `fireincident.txt` contains every actual fire reported to NFIRS that year.
# (No purely medical incidents, false alarms, etc. Only actual fires)

# %%
# get all fireincidents from given year in AZ
with open(f'{folderpath}/fireincident.txt','rb') as f:
    all_fires = pd.read_csv(f, sep="^", encoding="ISO-8859-1")

all_fires = all_fires[all_fires['STATE'] == 'AZ']
# Out:
# C:\Users\avuon\AppData\Local\Temp\ipykernel_5500\546489513.py:2: DtypeWarning: Columns (2,14,15,16,17,25,38,77,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_fires = pd.read_csv(f, sep="^", encoding="ISO-8859-1")
# <class 'pandas.core.frame.DataFrame'>
# Index: 16525 entries, 29817 to 46341
# Data columns (total 63 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INCIDENT_KEY  16525 non-null  object
#  1   STATE         16525 non-null  object
#  2   FDID          16525 non-null  object
#  3   INC_DATE      16525 non-null  int64
#  4   INC_NO        16525 non-null  int64
#  5   EXP_NO        16525 non-null  int64
#  6   VERSION       16525 non-null  float64
#  7   NUM_UNIT      14091 non-null  float64
#  8   NOT_RES       9134 non-null   object
#  9   BLDG_INVOL    3309 non-null   float64
#  10  ACRES_BURN    1492 non-null   float64
#  11  LESS_1ACRE    7000 non-null   object
#  12  ON_SITE_M1    12056 non-null  object
#  13  MAT_STOR1     8808 non-null   object
#  14  ON_SITE_M2    24 non-null     object
#  15  MAT_STOR2     24 non-null     object
#  16  ON_SITE_M3    9 non-null      object
#  17  MAT_STOR3     9 non-null      object
#  18  AREA_ORIG     16525 non-null  object
#  19  HEAT_SOURC    16525 non-null  object
#  20  FIRST_IGN     16525 non-null  object
#  21  CONF_ORIG     1567 non-null   float64
#  22  TYPE_MAT      10490 non-null  object
#  23  CAUSE_IGN     16525 non-null  object
#  24  FACT_IGN_1    16496 non-null  object
#  25  FACT_IGN_2    86 non-null     object
#  26  HUM_FAC_1     15256 non-null  object
#  27  HUM_FAC_2     200 non-null    float64
#  28  HUM_FAC_3     705 non-null    float64
#  29  HUM_FAC_4     86 non-null     float64
#  30  HUM_FAC_5     17 non-null     float64
#  31  HUM_FAC_6     147 non-null    float64
#  32  HUM_FAC_7     116 non-null    float64
#  33  HUM_FAC_8     0 non-null      float64
#  34  AGE           121 non-null    float64
#  35  SEX           133 non-null    float64
#  36  EQUIP_INV     4441 non-null   object
#  37  SUP_FAC_1     4383 non-null   object
#  38  SUP_FAC_2     55 non-null     object
#  39  SUP_FAC_3     31 non-null     float64
#  40  FIRE_SPRD     3277 non-null   float64
#  41  STRUC_TYPE    3393 non-null   float64
#  42  STRUC_STAT    3282 non-null   object
#  43  BLDG_ABOVE    3272 non-null   float64
#  44  BLDG_BELOW    3270 non-null   float64
#  45  BLDG_LGTH     190 non-null    float64
#  46  BLDG_WIDTH    190 non-null    float64
#  47  TOT_SQ_FT     3085 non-null   float64
#  48  FIRE_ORIG     3274 non-null   float64
#  49  FLAME_SPRD    16525 non-null  object
#  50  ITEM_SPRD     470 non-null    object
#  51  MAT_SPRD      288 non-null    object
#  52  DETECTOR      3262 non-null   object
#  53  DET_TYPE      1369 non-null   object
#  54  DET_POWER     1369 non-null   object
#  55  DET_OPERAT    1369 non-null   object
#  56  DET_EFFECT    684 non-null    object
#  57  DET_FAIL      250 non-null    object
#  58  AES_PRES      3268 non-null   object
#  59  AES_TYPE      227 non-null    object
#  60  AES_OPER      242 non-null    object
#  61  NO_SPR_OP     165 non-null    float64
#  62  AES_FAIL      75 non-null     object
# dtypes: float64(24), int64(3), object(36)
# memory usage: 8.1+ MB

# %% [markdown]
# Create another lookup table that matches database column names to their long English names.

# %%
# match up column shortnames to their longnames
col_names_long = ["Fire Dept. State", "Fire Dept. ID", "Incident Date", "Incident Number", "Exposure Number", "NFIRS Data Version", "Number of Residential Units", "Not Residential Flag", "Number of Buildings Involved", "Acres Burned", "Less Than One Acre", "On Site Materials #1", "Material Storage Use #1", "On Site Materials #2", "Material Storage Use #2", "On Site Materials #3", "Material Storage Use #3", "Area of Origin", "Heat Source", "Item First Ignited", "Confined To Origin", "Type of Material", "Cause of Ignition", "Factors Contributing To Ignition #1", "Factors Contributing To Ignition #2", "Human Factors #1", "Human Factors #2", "Human Factors #3", "Human Factors #4", "Human Factors #5", "Human Factors #6", "Human Factors #7", "Human Factors #8", "Age of Person", "Sex of Person", "Equipment Involved", "Suppression Factors #1", "Suppression Factors #2", "Suppression Factors #3", "Mobile Property Involved", "Mobile Property Type", "Mobile Property Make",
                  "Mobile Property Model", "Mobile Property Year", "Mobile Property License Plate", "Mobile Property State", "Mobile Property VIN Number", "Equipment Brand", "Equipment Model", "Equipment Serial Number", "Equipment Year", "Equipment Power", "Equipment Portability", "Fire Spread", "Structure Type", "Structure Status", "Building Height: Stories Above Grade", "Building Height: Stories Below Grade", "Building Length", "Building Width", "Total Square Feet", "Fire Origin (starting story)", "Number of Stories with Damage: Minor", "Number of Stories with Damage: Significant", "Number of Stories with Damage: Heavy", "Number of Stories with Damage: Extreme", "No Flame Spread/Same As First/Unknown", "Item Contributing Most to Spread", "Type Material Contributing Most To Spread", "Detector Presence", "Detector Type", "Detector Power", "Detector Operation", "Detector Effectiveness", "Detector Failure Reason", "AES Presence", "AES Type", "AES Operation", "Number of Sprinklers Operating", "AES Failure Reason",]

lookup_fire = dict(zip(all_fires.columns[1:],col_names_long))

all_fires = all_fires.loc[:, ~all_fires.columns.str.startswith(('MOB_','EQ_','ST_DAM_'))]

all_fires.info()

# %% [markdown]
# `incidentaddress.txt` contains the address of every NFIRS datapoint that year. Including non-fires.
#
# This is where we can filter down to Tempe only.

# %%
with open(f'{folderpath}/incidentaddress.txt','rb') as f:
    addresses = pd.read_csv(f, sep="^", encoding="ISO-8859-1")

address_col_long_names = ["Fire Dept. State", "Fire Dept. ID", "Incident Date", "Incident Number", "Exposure Number", "Location Type", "Number or Milepost",
                          "Street Prefix", "Street or Highway Name", "Street Type", "Street Suffix", "Apartment Number", "City", "State", "Zip 5", "Zip 4", "Cross Street or Directions",]
lookup_addr = dict(zip(addresses.columns[1:],address_col_long_names))

addresses = addresses[addresses['STATE'] == 'AZ']
addresses = addresses[addresses['CITY'] == 'Tempe']
addresses = addresses.drop(['STREETSUF','APT_NO','ZIP4'],axis=1) # Data is usually not helpful
#TODO STREETSUF is necessary sometimes for geocoding errors, but causes other errors too
addresses.head()

# %%
lookup_addr.update(lookup_fire) # merge the two lookup tables
lookup = lookup_addr #convenience rename
# Out:
# {'STATE': 'Fire Dept. State',
#  'FDID': 'Fire Dept. ID',
#  'INC_DATE': 'Incident Date',
#  'INC_NO': 'Incident Number',
#  'EXP_NO': 'Exposure Number',
#  'LOC_TYPE': 'Location Type',
#  'NUM_MILE': 'Number or Milepost',
#  'STREET_PRE': 'Street Prefix',
#  'STREETNAME': 'Street or Highway Name',
#  'STREETTYPE': 'Street Type',
#  'STREETSUF': 'Street Suffix',
#  'APT_NO': 'Apartment Number',
#  'CITY': 'City',
#  'STATE_ID': 'State',
#  'ZIP5': 'Zip 5',
#  'ZIP4': 'Zip 4',
#  'X_STREET': 'Cross Street or Directions',
#  'VERSION': 'NFIRS Data Version',
#  'NUM_UNIT': 'Number of Residential Units',
#  'NOT_RES': 'Not Residential Flag',
#  'BLDG_INVOL': 'Number of Buildings Involved',
#  'ACRES_BURN': 'Acres Burned',
#  'LESS_1ACRE': 'Less Than One Acre',
#  'ON_SITE_M1': 'On Site Materials #1',
#  'MAT_STOR1': 'Material Storage Use #1',
#  'ON_SITE_M2': 'On Site Materials #2',
#  'MAT_STOR2': 'Material Storage Use #2',
#  'ON_SITE_M3': 'On Site Materials #3',
#  'MAT_STOR3': 'Material Storage Use #3',
#  'AREA_ORIG': 'Area of Origin',
#  'HEAT_SOURC': 'Heat Source',
#  'FIRST_IGN': 'Item First Ignited',
#  'CONF_ORIG': 'Confined To Origin',
#  'TYPE_MAT': 'Type of Material',
#  'CAUSE_IGN': 'Cause of Ignition',
#  'FACT_IGN_1': 'Factors Contributing To Ignition #1',
#  'FACT_IGN_2': 'Factors Contributing To Ignition #2',
#  'HUM_FAC_1': 'Human Factors #1',
#  'HUM_FAC_2': 'Human Factors #2',
#  'HUM_FAC_3': 'Human Factors #3',
#  'HUM_FAC_4': 'Human Factors #4',
#  'HUM_FAC_5': 'Human Factors #5',
#  'HUM_FAC_6': 'Human Factors #6',
#  'HUM_FAC_7': 'Human Factors #7',
#  'HUM_FAC_8': 'Human Factors #8',
#  'AGE': 'Age of Person',
#  'SEX': 'Sex of Person',
#  'EQUIP_INV': 'Equipment Involved',
#  'SUP_FAC_1': 'Suppression Factors #1',
#  'SUP_FAC_2': 'Suppression Factors #2',
#  'SUP_FAC_3': 'Suppression Factors #3',
#  'MOB_INVOL': 'Mobile Property Involved',
#  'MOB_TYPE': 'Mobile Property Type',
#  'MOB_MAKE': 'Mobile Property Make',
#  'MOB_MODEL': 'Mobile Property Model',
#  'MOB_YEAR': 'Mobile Property Year',
#  'MOB_LIC_PL': 'Mobile Property License Plate',
#  'MOB_STATE': 'Mobile Property State',
#  'MOB_VIN_NO': 'Mobile Property VIN Number',
#  'EQ_BRAND': 'Equipment Brand',
#  'EQ_MODEL': 'Equipment Model',
#  'EQ_SER_NO': 'Equipment Serial Number',
#  'EQ_YEAR': 'Equipment Year',
#  'EQ_POWER': 'Equipment Power',
#  'EQ_PORT': 'Equipment Portability',
#  'FIRE_SPRD': 'Fire Spread',
#  'STRUC_TYPE': 'Structure Type',
#  'STRUC_STAT': 'Structure Status',
#  'BLDG_ABOVE': 'Building Height: Stories Above Grade',
#  'BLDG_BELOW': 'Building Height: Stories Below Grade',
#  'BLDG_LGTH': 'Building Length',
#  'BLDG_WIDTH': 'Building Width',
#  'TOT_SQ_FT': 'Total Square Feet',
#  'FIRE_ORIG': 'Fire Origin (starting story)',
#  'ST_DAM_MIN': 'Number of Stories with Damage: Minor',
#  'ST_DAM_SIG': 'Number of Stories with Damage: Significant',
#  'ST_DAM_HVY': 'Number of Stories with Damage: Heavy',
#  'ST_DAM_XTR': 'Number of Stories with Damage: Extreme',
#  'FLAME_SPRD': 'No Flame Spread/Same As First/Unknown',
#  'ITEM_SPRD': 'Item Contributing Most to Spread',
#  'MAT_SPRD': 'Type Material Contributing Most To Spread',
#  'DETECTOR': 'Detector Presence',
#  'DET_TYPE': 'Detector Type',
#  'DET_POWER': 'Detector Power',
#  'DET_OPERAT': 'Detector Operation',
#  'DET_EFFECT': 'Detector Effectiveness',
#  'DET_FAIL': 'Detector Failure Reason',
#  'AES_PRES': 'AES Presence',
#  'AES_TYPE': 'AES Type',
#  'AES_OPER': 'AES Operation',
#  'NO_SPR_OP': 'Number of Sprinklers Operating',
#  'AES_FAIL': 'AES Failure Reason'}

# %% [markdown]
# Merge `fireincident` and `incidentaddress` together, dropping any fires which don't occur in Tempe, AZ

# %%
all_fires = all_fires.drop(['STATE', 'FDID', 'INC_DATE', 'INC_NO', 'EXP_NO'], axis=1)
fires_in_tempe = addresses.merge(all_fires, on='INCIDENT_KEY', how='inner')
# remove decimal point from zipcode
fires_in_tempe['ZIP5'] = fires_in_tempe['ZIP5'].astype(int)

#coerce col dtypes to help plaintext formatting look better
fires_in_tempe = fires_in_tempe.apply(lambda x: x.astype('int',errors='ignore') if x.dtype == 'float64' else x)
fires_in_tempe = fires_in_tempe.apply(lambda x: x.astype('object',errors='ignore') if x.dtype == 'float64' else x)
fires_in_tempe.map(lambda x: x.rstrip('.0') if isinstance(x,str) else x) # failed attempt to prevent decimals rendering in plaintext
fires_in_tempe.head()
# Out:
#                   INCIDENT_KEY STATE   FDID  INC_DATE   INC_NO  EXP_NO  \
# 0    AZ_08052_01022023_23164_0    AZ  08052   1022023    23164       0
# 1   AZ_08052_01102023_231089_0    AZ  08052   1102023   231089       0
# 2  AZ_08052_05112023_2314733_0    AZ  08052   5112023  2314733       0
# 3  AZ_08052_05132023_2315036_0    AZ  08052   5132023  2315036       0
# 4  AZ_08052_06142023_2318787_0    AZ  08052   6142023  2318787       0
#
#    LOC_TYPE NUM_MILE STREET_PRE STREETNAME STREETTYPE   CITY STATE_ID   ZIP5  \
# 0         1     2145          E     WARNER         RD  Tempe       AZ  85284
# 1         1     9631          S    LA ROSA         DR  Tempe       AZ  85284
# 2         1     1475          W     ELLIOT         RD  Tempe       AZ  85284
# 3         1      401          W      ORION         ST  Tempe       AZ  85283
# 4         1     1905          E     VELVET         DR  Tempe       AZ  85284
#
#   X_STREET  VERSION NUM_UNIT NOT_RES BLDG_INVOL ACRES_BURN LESS_1ACRE  \
# 0      NaN        5      NaN       N        NaN        NaN        NaN
# 1      NaN        5      1.0       N        NaN        NaN        NaN
# 2      NaN        5      0.0       Y        1.0        NaN        NaN
# 3      NaN        5      NaN       N        NaN        NaN          N
# 4      NaN        5      1.0       N        1.0        NaN        NaN
#
#   ON_SITE_M1 MAT_STOR1 ON_SITE_M2 MAT_STOR2 ON_SITE_M3 MAT_STOR3 AREA_ORIG  \
# 0        240         N        NaN       NaN        NaN       NaN        00
# 1        NaN       NaN        NaN       NaN        NaN       NaN        24
# 2        UUU         U        NaN       NaN        NaN       NaN        UU
# 3        NaN       NaN        NaN       NaN        NaN       NaN        UU
# 4        UUU         U        NaN       NaN        NaN       NaN        93
#
#   HEAT_SOURC FIRST_IGN CONF_ORIG TYPE_MAT CAUSE_IGN FACT_IGN_1 FACT_IGN_2  \
# 0         13        25       NaN       41         2         20        NaN
# 1         10        76       NaN      NaN         2         00        NaN
# 2         UU        UU       NaN      NaN         U         UU        NaN
# 3         UU        UU       NaN      NaN         U         UU        NaN
# 4         UU        UU       NaN      NaN         U         UU        NaN
#
#   HUM_FAC_1 HUM_FAC_2 HUM_FAC_3 HUM_FAC_4 HUM_FAC_5 HUM_FAC_6 HUM_FAC_7  \
# 0         N       NaN       NaN       NaN       NaN       NaN       NaN
# 1         N       NaN       NaN       NaN       NaN       NaN       NaN
# 2         N       NaN       NaN       NaN       NaN       NaN       NaN
# 3         N       NaN       NaN       NaN       NaN       NaN       NaN
# 4         N       NaN       NaN       NaN       NaN       NaN       NaN
#
#   HUM_FAC_8  AGE  SEX EQUIP_INV SUP_FAC_1 SUP_FAC_2 SUP_FAC_3 FIRE_SPRD  \
# 0       NaN  NaN  NaN       NNN       NNN       NaN       NaN       NaN
# 1       NaN  NaN  NaN       NNN       NNN       NaN       NaN       NaN
# 2       NaN  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN  NaN  NaN       NNN       NNN       NaN       NaN       NaN
# 4       NaN  NaN  NaN       NNN       NNN       NaN       NaN       NaN
#
#   STRUC_TYPE STRUC_STAT BLDG_ABOVE BLDG_BELOW BLDG_LGTH BLDG_WIDTH TOT_SQ_FT  \
# 0        NaN        NaN        NaN        NaN       NaN        NaN       NaN
# 1        NaN        NaN        NaN        NaN       NaN        NaN       NaN
# 2        NaN        NaN        NaN        NaN       NaN        NaN       NaN
# 3        NaN        NaN        NaN        NaN       NaN        NaN       NaN
# 4        NaN        NaN        NaN        NaN       NaN        NaN       NaN
#
#   FIRE_ORIG FLAME_SPRD ITEM_SPRD MAT_SPRD DETECTOR DET_TYPE DET_POWER  \
# 0       NaN          Y       NaN      NaN      NaN      NaN       NaN
# 1       NaN          Y       NaN      NaN      NaN      NaN       NaN
# 2       NaN          Y       NaN      NaN      NaN      NaN       NaN
# 3       NaN          Y       NaN      NaN      NaN      NaN       NaN
# 4       NaN          Y       NaN      NaN      NaN      NaN       NaN
#
#   DET_OPERAT DET_EFFECT DET_FAIL AES_PRES AES_TYPE AES_OPER NO_SPR_OP AES_FAIL
# 0        NaN        NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 1        NaN        NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 2        NaN        NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 3        NaN        NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 4        NaN        NaN      NaN      NaN      NaN      NaN       NaN      NaN

# %% [markdown]
# `LOC_TYPE` 1 and 3 represent building fires. 2 often is for vehicle fires / car-crash fires, which have crossroads instead of full addresses and are much harder to geocode.
#
# Drop #2-type fires here.

# %%
def parse_addr_1(row):
    if row['LOC_TYPE'] not in (1,3):
        return None
    addr = list(row.iloc[7:14])
    addr = [str(x) if pd.notna(x) else '' for x in addr]
    addr = [x.strip() for x in addr if x.strip() != '']
    return ' '.join(addr)

fires_in_tempe['_addr'] = fires_in_tempe.apply(lambda x: parse_addr_1(x), axis=1)

# %% [markdown]
# For each cell in the non-address columns, replace the ID with its corresponding text from the lookup table.
#
# This way we get to see that ON_SITE_M1=531 actually means a fire with charcoal fuel. Easier to read later, but harder to store

# %%
temp = pd.DataFrame()

def match_code_to_lookup_name(val,colname):
    if isinstance(val,float) and not pd.isna(val):
        val = int(val)
    a = lookup_table.loc[(lookup_table['fieldid'] == colname) & (lookup_table['code_value'] == str(val)), 'code_descr'].values
    return a

for col in fires_in_tempe.columns[17:]:
    # if col not in lookup:
        # continue
    temp[col] = fires_in_tempe[col].map(lambda x: match_code_to_lookup_name(x,col))

temp = temp.map(lambda x: x[0] if len(list(x))>0 else None)
for col in temp.columns:
    temp[col] = temp[col].map(lambda x: str(lookup[col] + ': ' + str(x) if not pd.isna(x) else x))

# %% [markdown]
# A lot of None values got turned to strings here. Fix those, and also deal with N/NN/NNN, which are generic codes for NFIRS missing data.

# %%
temp.replace(['None', 'nan', 'NaN'], np.nan, inplace=True)
# temp
fires_in_tempe.update(temp)
fires_in_tempe.replace(["N", "NN", "NNN"], np.nan, inplace=True)
# Out:
# C:\Users\avuon\AppData\Local\Temp\ipykernel_5500\389832939.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   temp.replace(['None', 'nan', 'NaN'], np.nan, inplace=True)
# C:\Users\avuon\AppData\Local\Temp\ipykernel_5500\389832939.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   fires_in_tempe.replace(["N", "NN", "NNN"], np.nan, inplace=True)

# %% [markdown]
# Move the `_addr` column to the front, then drop a couple columns which have info we don't need.

# %%
cols = fires_in_tempe.columns.tolist()
cols.insert(1,cols.pop())
fires_in_tempe = fires_in_tempe[cols]
fires_in_tempe.drop(['FLAME_SPRD','VERSION'],axis=1,inplace=True)

# %% [markdown]
# Coerce dtypes again, then change the mm-dd-yyyy date string to an actual timestamp

# %%
fires_in_tempe = fires_in_tempe.convert_dtypes()
fires_in_tempe['INC_DATE'] = pd.to_datetime(fires_in_tempe['INC_DATE'], format='%m%d%Y', errors='coerce')

# %%
# Verify data here to make sure column count and labels match
for col in fires_in_tempe.columns:
    print(col,fires_in_tempe[col].dtype,lookup.get(col))
# Out:
# INCIDENT_KEY string None
# _addr string None
# STATE string Fire Dept. State
# FDID string Fire Dept. ID
# INC_DATE datetime64[ns] Incident Date
# INC_NO Int64 Incident Number
# EXP_NO Int64 Exposure Number
# LOC_TYPE Int32 Location Type
# NUM_MILE string Number or Milepost
# STREET_PRE string Street Prefix
# STREETNAME string Street or Highway Name
# STREETTYPE string Street Type
# CITY string City
# STATE_ID string State
# ZIP5 Int32 Zip 5
# X_STREET string Cross Street or Directions
# NUM_UNIT Int64 Number of Residential Units
# NOT_RES string Not Residential Flag
# BLDG_INVOL Int64 Number of Buildings Involved
# ACRES_BURN Int64 Acres Burned
# LESS_1ACRE string Less Than One Acre
# ON_SITE_M1 string On Site Materials #1
# MAT_STOR1 string Material Storage Use #1
# ON_SITE_M2 Int64 On Site Materials #2
# MAT_STOR2 Int64 Material Storage Use #2
# ON_SITE_M3 Int64 On Site Materials #3
# MAT_STOR3 Int64 Material Storage Use #3
# AREA_ORIG string Area of Origin
# HEAT_SOURC string Heat Source
# FIRST_IGN string Item First Ignited
# CONF_ORIG string Confined To Origin
# TYPE_MAT string Type of Material
# CAUSE_IGN string Cause of Ignition
# FACT_IGN_1 string Factors Contributing To Ignition #1
# FACT_IGN_2 string Factors Contributing To Ignition #2
# HUM_FAC_1 string Human Factors #1
# HUM_FAC_2 string Human Factors #2
# HUM_FAC_3 string Human Factors #3
# HUM_FAC_4 string Human Factors #4
# HUM_FAC_5 Int64 Human Factors #5
# HUM_FAC_6 string Human Factors #6
# HUM_FAC_7 string Human Factors #7
# HUM_FAC_8 Int64 Human Factors #8
# AGE Int64 Age of Person
# SEX Int64 Sex of Person
# EQUIP_INV string Equipment Involved
# SUP_FAC_1 string Suppression Factors #1
# SUP_FAC_2 Int64 Suppression Factors #2
# SUP_FAC_3 Int64 Suppression Factors #3
# FIRE_SPRD string Fire Spread
# STRUC_TYPE string Structure Type
# STRUC_STAT string Structure Status
# BLDG_ABOVE Int64 Building Height: Stories Above Grade
# BLDG_BELOW Int64 Building Height: Stories Below Grade
# BLDG_LGTH Int64 Building Length
# BLDG_WIDTH Int64 Building Width
# TOT_SQ_FT Int64 Total Square Feet
# FIRE_ORIG Int64 Fire Origin (starting story)
# ITEM_SPRD string Item Contributing Most to Spread
# MAT_SPRD string Type Material Contributing Most To Spread
# DETECTOR string Detector Presence
# DET_TYPE string Detector Type
# DET_POWER string Detector Power
# DET_OPERAT string Detector Operation
# DET_EFFECT string Detector Effectiveness
# DET_FAIL string Detector Failure Reason
# AES_PRES string AES Presence
# AES_TYPE string AES Type
# AES_OPER string AES Operation
# NO_SPR_OP Int64 Number of Sprinklers Operating
# AES_FAIL string AES Failure Reason

# %% [markdown]
# Some of the fire-data columns have numeric data, like occupant age, number of stories above ground, etc.
#
# We label them similarly to the categorical data columns, changing `NO_SPR_OP=2` to "Number of Sprinklers Operating: 2" for readability

# %%
numeric_cols = ["NUM_UNIT","NOT_RES","LESS_1ACRE","AGE","SEX","BLDG_INVOL","ACRES_BURN","BLDG_ABOVE","BLDG_BELOW","BLDG_LGTH","BLDG_WIDTH","TOT_SQ_FT","FIRE_ORIG","NO_SPR_OP"]

def label(val,colname):
    if not pd.isna(val):
        return f"{lookup[colname]}: {str(val)}"
    else:
        return val

for col in fires_in_tempe[numeric_cols].columns:
    fires_in_tempe[col] = fires_in_tempe[col].map(lambda val: label(val,col))

# %% [markdown]
# Check here for missed cols, data errors, and bad addresses

# %%
fires_in_tempe.sample(10)
# Out:
#                     INCIDENT_KEY                                _addr STATE  \
# 25     AZ_08293_01112023_23941_0       1800 E LIBRA DR Tempe AZ 85283    AZ
# 323  AZ_08293_10282023_2328438_0      3207 S WILSON ST Tempe AZ 85282    AZ
# 303  AZ_08293_09302023_2325835_0        1350 W 14TH ST Tempe AZ 85281    AZ
# 377  AZ_08293_12182023_2332972_0        738 S PERRY LN Tempe AZ 85281    AZ
# 159  AZ_08293_05152023_2312404_0                                 <NA>    AZ
# 181  AZ_08293_06012023_2314024_0  1003 W WASHINGTON ST Tempe AZ 85281    AZ
# 276  AZ_08293_09062023_2323552_0     1080 E GILBERT DR Tempe AZ 85281    AZ
# 52    AZ_08293_02172023_234188_0       1750 S PRICE RD Tempe AZ 85281    AZ
# 103   AZ_08293_04052023_238522_0        1259 S LOLA LN Tempe AZ 85281    AZ
# 360  AZ_08293_12012023_2331562_0    1235 W BASELINE RD Tempe AZ 85283    AZ
#
#       FDID   INC_DATE   INC_NO  EXP_NO  LOC_TYPE NUM_MILE STREET_PRE  \
# 25   08293 2023-11-01    23941       0         1     1800          E
# 323  08293 2023-10-28  2328438       0         1     3207          S
# 303  08293 2023-09-30  2325835       0         3     1350          W
# 377  08293 2023-12-18  2332972       0         1      738          S
# 159  08293 2023-05-15  2312404       0         2     <NA>       <NA>
# 181  08293 2023-06-01  2314024       0         1     1003          W
# 276  08293 2023-09-06  2323552       0         1     1080          E
# 52   08293 2023-02-17   234188       0         1     1750          S
# 103  08293 2023-04-05   238522       0         1     1259          S
# 360  08293 2023-12-01  2331562       0         1     1235          W
#
#      STREETNAME STREETTYPE   CITY STATE_ID   ZIP5            X_STREET  \
# 25        LIBRA         DR  Tempe       AZ  85283                <NA>
# 323      WILSON         ST  Tempe       AZ  85282                <NA>
# 303        14TH         ST  Tempe       AZ  85281                <NA>
# 377       PERRY         LN  Tempe       AZ  85281                <NA>
# 159        A101       <NA>  Tempe       AZ  85281  RIO SALADO PW NB S
# 181  WASHINGTON         ST  Tempe       AZ  85281                <NA>
# 276     GILBERT         DR  Tempe       AZ  85281     N SCOTTSDALE RD
# 52        PRICE         RD  Tempe       AZ  85281                <NA>
# 103        LOLA         LN  Tempe       AZ  85281                <NA>
# 360    BASELINE         RD  Tempe       AZ  85283                <NA>
#
#                                NUM_UNIT                  NOT_RES  \
# 25                                  NaN                     <NA>
# 323                                 NaN                     <NA>
# 303    Number of Residential Units: 0.0  Not Residential Flag: Y
# 377    Number of Residential Units: 0.0  Not Residential Flag: Y
# 159                                 NaN  Not Residential Flag: Y
# 181  Number of Residential Units: 300.0                     <NA>
# 276                                 NaN                     <NA>
# 52                                  NaN                     <NA>
# 103    Number of Residential Units: 1.0                     <NA>
# 360   Number of Residential Units: 13.0                     <NA>
#
#                             BLDG_INVOL ACRES_BURN             LESS_1ACRE  \
# 25                                 NaN        NaN                   <NA>
# 323                                NaN        NaN                   <NA>
# 303                                NaN        NaN                   <NA>
# 377  Number of Buildings Involved: 1.0        NaN  Less Than One Acre: Y
# 159  Number of Buildings Involved: 0.0        NaN                   <NA>
# 181  Number of Buildings Involved: 1.0        NaN  Less Than One Acre: Y
# 276                                NaN        NaN                   <NA>
# 52                                 NaN        NaN                   <NA>
# 103                                NaN        NaN                   <NA>
# 360  Number of Buildings Involved: 1.0        NaN                   <NA>
#
#                                             ON_SITE_M1  \
# 25                                                <NA>
# 323  On Site Materials #1: Personal & home products...
# 303                                               <NA>
# 377                   On Site Materials #1: Insulation
# 159                                               <NA>
# 181                                               <NA>
# 276                        On Site Materials #1: Tires
# 52                                                <NA>
# 103                                               <NA>
# 360                                               <NA>
#
#                                              MAT_STOR1  ON_SITE_M2  MAT_STOR2  \
# 25                                                <NA>        <NA>       <NA>
# 323  Material Storage Use #1: Bulk storage or wareh...        <NA>       <NA>
# 303                                               <NA>        <NA>       <NA>
# 377         Material Storage Use #1: Repair or service        <NA>       <NA>
# 159                                               <NA>        <NA>       <NA>
# 181                                               <NA>        <NA>       <NA>
# 276  Material Storage Use #1: Bulk storage or wareh...        <NA>       <NA>
# 52                                                <NA>        <NA>       <NA>
# 103                                               <NA>        <NA>       <NA>
# 360                                               <NA>        <NA>       <NA>
#
#      ON_SITE_M3  MAT_STOR3                                          AREA_ORIG  \
# 25         <NA>       <NA>  Area of Origin: Engine area, running gear, whe...
# 323        <NA>       <NA>    Area of Origin: Cargo/trunk area - all vehicles
# 303        <NA>       <NA>                              Area of Origin: Other
# 377        <NA>       <NA>                Area of Origin: Storage area, other
# 159        <NA>       <NA>  Area of Origin: Highway, parking lot, street: ...
# 181        <NA>       <NA>              Area of Origin: Cooking area, kitchen
# 276        <NA>       <NA>                Area of Origin: Vehicle area, other
# 52         <NA>       <NA>                       Area of Origin: Undetermined
# 103        <NA>       <NA>                       Area of Origin: Undetermined
# 360        <NA>       <NA>              Area of Origin: Cooking area, kitchen
#
#                                             HEAT_SOURC  \
# 25                           Heat Source: Undetermined
# 323                          Heat Source: Undetermined
# 303                    Heat Source: Heat source: other
# 377  Heat Source: Radiated, conducted heat from ope...
# 159    Heat Source: Heat from powered equipment, other
# 181       Heat Source: Hot or smoldering object, other
# 276                          Heat Source: Undetermined
# 52                           Heat Source: Undetermined
# 103    Heat Source: Heat from powered equipment, other
# 360    Heat Source: Heat from powered equipment, other
#
#                                              FIRST_IGN CONF_ORIG  \
# 25                    Item First Ignited: Undetermined      <NA>
# 323                   Item First Ignited: Undetermined      <NA>
# 303      Item First Ignited: Item First Ignited, Other      <NA>
# 377                   Item First Ignited: Undetermined      <NA>
# 159                           Item First Ignited: Tire      <NA>
# 181      Item First Ignited: Item First Ignited, Other      <NA>
# 276                   Item First Ignited: Undetermined      <NA>
# 52                    Item First Ignited: Undetermined      <NA>
# 103                   Item First Ignited: Undetermined      <NA>
# 360  Item First Ignited: Cooking materials, includi...      <NA>
#
#                                               TYPE_MAT  \
# 25                                                <NA>
# 323                                               <NA>
# 303       Type of Material: Multiple types of material
# 377                     Type of Material: Undetermined
# 159                                               <NA>
# 181                          Type of Material: Plastic
# 276                                               <NA>
# 52                                                <NA>
# 103                                               <NA>
# 360  Type of Material: Cooking oil, transformer or ...
#
#                                              CAUSE_IGN  \
# 25                    Cause of Ignition: Unintentional
# 323                   Cause of Ignition: Unintentional
# 303                   Cause of Ignition: Unintentional
# 377                   Cause of Ignition: Unintentional
# 159                   Cause of Ignition: Unintentional
# 181                   Cause of Ignition: Unintentional
# 276       Cause of Ignition: Cause under investigation
# 52   Cause of Ignition: Cause undetermined after in...
# 103                   Cause of Ignition: Unintentional
# 360                   Cause of Ignition: Unintentional
#
#                                             FACT_IGN_1 FACT_IGN_2  \
# 25   Factors Contributing To Ignition #1: Undetermined       <NA>
# 323  Factors Contributing To Ignition #1: Undetermined       <NA>
# 303  Factors Contributing To Ignition #1: Other fac...       <NA>
# 377  Factors Contributing To Ignition #1: Heat sour...       <NA>
# 159  Factors Contributing To Ignition #1: Undetermined       <NA>
# 181  Factors Contributing To Ignition #1: Accidenta...       <NA>
# 276  Factors Contributing To Ignition #1: Undetermined       <NA>
# 52   Factors Contributing To Ignition #1: Undetermined       <NA>
# 103  Factors Contributing To Ignition #1: Misuse of...       <NA>
# 360                                               <NA>       <NA>
#
#                     HUM_FAC_1 HUM_FAC_2  \
# 25                       <NA>      <NA>
# 323                      <NA>      <NA>
# 303                      <NA>      <NA>
# 377                      <NA>      <NA>
# 159                      <NA>      <NA>
# 181                      <NA>      <NA>
# 276                      <NA>      <NA>
# 52                       <NA>      <NA>
# 103                      <NA>      <NA>
# 360  Human Factors #1: Asleep      <NA>
#
#                                              HUM_FAC_3 HUM_FAC_4  HUM_FAC_5  \
# 25                                                <NA>      <NA>       <NA>
# 323                                               <NA>      <NA>       <NA>
# 303                                               <NA>      <NA>       <NA>
# 377  Human Factors #3: Unattended or unsupervised p...      <NA>       <NA>
# 159                                               <NA>      <NA>       <NA>
# 181                                               <NA>      <NA>       <NA>
# 276                                               <NA>      <NA>       <NA>
# 52                                                <NA>      <NA>       <NA>
# 103                                               <NA>      <NA>       <NA>
# 360                                               <NA>      <NA>       <NA>
#
#     HUM_FAC_6 HUM_FAC_7  HUM_FAC_8  AGE  SEX  \
# 25       <NA>      <NA>       <NA>  NaN  NaN
# 323      <NA>      <NA>       <NA>  NaN  NaN
# 303      <NA>      <NA>       <NA>  NaN  NaN
# 377      <NA>      <NA>       <NA>  NaN  NaN
# 159      <NA>      <NA>       <NA>  NaN  NaN
# 181      <NA>      <NA>       <NA>  NaN  NaN
# 276      <NA>      <NA>       <NA>  NaN  NaN
# 52       <NA>      <NA>       <NA>  NaN  NaN
# 103      <NA>      <NA>       <NA>  NaN  NaN
# 360      <NA>      <NA>       <NA>  NaN  NaN
#
#                                              EQUIP_INV  \
# 25                                                <NA>
# 323                                               <NA>
# 303                                               <NA>
# 377  Equipment Involved: Heater, excluding catalyti...
# 159                                               <NA>
# 181  Equipment Involved: Range, stove with/without ...
# 276                                               <NA>
# 52                                                <NA>
# 103                                               <NA>
# 360                                               <NA>
#
#                                              SUP_FAC_1  SUP_FAC_2  SUP_FAC_3  \
# 25                                                <NA>       <NA>       <NA>
# 323                                               <NA>       <NA>       <NA>
# 303                                               <NA>       <NA>       <NA>
# 377                                               <NA>       <NA>       <NA>
# 159                                               <NA>       <NA>       <NA>
# 181  Suppression Factors #1: Alarm System inappropr...       <NA>       <NA>
# 276                                               <NA>       <NA>       <NA>
# 52                                                <NA>       <NA>       <NA>
# 103                                               <NA>       <NA>       <NA>
# 360                                               <NA>       <NA>       <NA>
#
#                                    FIRE_SPRD  \
# 25                                      <NA>
# 323                                     <NA>
# 303                                     <NA>
# 377  Fire Spread: Confined to room of origin
# 159                                     <NA>
# 181  Fire Spread: Confined to room of origin
# 276                                     <NA>
# 52                                      <NA>
# 103  Fire Spread: Confined to room of origin
# 360  Fire Spread: Confined to room of origin
#
#                             STRUC_TYPE                       STRUC_STAT  \
# 25                                <NA>                             <NA>
# 323                               <NA>                             <NA>
# 303                               <NA>                             <NA>
# 377  Structure Type: Enclosed building  Structure Status: In normal use
# 159                               <NA>                             <NA>
# 181  Structure Type: Enclosed building  Structure Status: In normal use
# 276                               <NA>                             <NA>
# 52                                <NA>                             <NA>
# 103  Structure Type: Enclosed building  Structure Status: In normal use
# 360  Structure Type: Enclosed building  Structure Status: In normal use
#
#                                     BLDG_ABOVE  \
# 25                                         NaN
# 323                                        NaN
# 303                                        NaN
# 377  Building Height: Stories Above Grade: 1.0
# 159                                        NaN
# 181  Building Height: Stories Above Grade: 3.0
# 276                                        NaN
# 52                                         NaN
# 103  Building Height: Stories Above Grade: 1.0
# 360  Building Height: Stories Above Grade: 3.0
#
#                                     BLDG_BELOW BLDG_LGTH BLDG_WIDTH  \
# 25                                         NaN       NaN        NaN
# 323                                        NaN       NaN        NaN
# 303                                        NaN       NaN        NaN
# 377  Building Height: Stories Below Grade: 0.0       NaN        NaN
# 159                                        NaN       NaN        NaN
# 181  Building Height: Stories Below Grade: 0.0       NaN        NaN
# 276                                        NaN       NaN        NaN
# 52                                         NaN       NaN        NaN
# 103  Building Height: Stories Below Grade: 0.0       NaN        NaN
# 360  Building Height: Stories Below Grade: 0.0       NaN        NaN
#
#                        TOT_SQ_FT                          FIRE_ORIG ITEM_SPRD  \
# 25                           NaN                                NaN      <NA>
# 323                          NaN                                NaN      <NA>
# 303                          NaN                                NaN      <NA>
# 377    Total Square Feet: 2500.0  Fire Origin (starting story): 1.0      <NA>
# 159                          NaN                                NaN      <NA>
# 181    Total Square Feet: 1000.0  Fire Origin (starting story): 3.0      <NA>
# 276                          NaN                                NaN      <NA>
# 52                           NaN                                NaN      <NA>
# 103    Total Square Feet: 6000.0  Fire Origin (starting story): 1.0      <NA>
# 360  Total Square Feet: 264000.0  Fire Origin (starting story): 2.0      <NA>
#
#                                               MAT_SPRD  \
# 25                                                <NA>
# 323                                               <NA>
# 303                                               <NA>
# 377                                               <NA>
# 159                                               <NA>
# 181  Type Material Contributing Most To Spread: Pla...
# 276                                               <NA>
# 52                                                <NA>
# 103                                               <NA>
# 360                                               <NA>
#
#                                  DETECTOR              DET_TYPE  \
# 25                                   <NA>                  <NA>
# 323                                  <NA>                  <NA>
# 303                                  <NA>                  <NA>
# 377       Detector Presence: None Present                  <NA>
# 159                                  <NA>                  <NA>
# 181       Detector Presence: None Present                  <NA>
# 276                                  <NA>                  <NA>
# 52                                   <NA>                  <NA>
# 103  Detector Presence: Detectors Present  Detector Type: Smoke
# 360  Detector Presence: Detectors Present  Detector Type: Smoke
#
#                                  DET_POWER                    DET_OPERAT  \
# 25                                    <NA>                          <NA>
# 323                                   <NA>                          <NA>
# 303                                   <NA>                          <NA>
# 377                                   <NA>                          <NA>
# 159                                   <NA>                          <NA>
# 181                                   <NA>                          <NA>
# 276                                   <NA>                          <NA>
# 52                                    <NA>                          <NA>
# 103                Detector Power: Unknown  Detector Operation: Operated
# 360  Detector Power: Hardwire with battery  Detector Operation: Operated
#
#                                             DET_EFFECT DET_FAIL  \
# 25                                                <NA>     <NA>
# 323                                               <NA>     <NA>
# 303                                               <NA>     <NA>
# 377                                               <NA>     <NA>
# 159                                               <NA>     <NA>
# 181                                               <NA>     <NA>
# 276                                               <NA>     <NA>
# 52                                                <NA>     <NA>
# 103          Detector Effectiveness: Alerted Occupants     <NA>
# 360  Detector Effectiveness: Occupants failed to re...     <NA>
#
#                        AES_PRES                      AES_TYPE  \
# 25                         <NA>                          <NA>
# 323                        <NA>                          <NA>
# 303                        <NA>                          <NA>
# 377  AES Presence: None Present                          <NA>
# 159                        <NA>                          <NA>
# 181       AES Presence: Present  AES Type: Wet pipe sprinkler
# 276                        <NA>                          <NA>
# 52                         <NA>                          <NA>
# 103       AES Presence: Present                          <NA>
# 360  AES Presence: None Present                          <NA>
#
#                                   AES_OPER  \
# 25                                    <NA>
# 323                                   <NA>
# 303                                   <NA>
# 377                                   <NA>
# 159                                   <NA>
# 181  AES Operation: Operated and Effective
# 276                                   <NA>
# 52                                    <NA>
# 103                                   <NA>
# 360                                   <NA>
#
#                                NO_SPR_OP AES_FAIL
# 25                                   NaN     <NA>
# 323                                  NaN     <NA>
# 303                                  NaN     <NA>
# 377                                  NaN     <NA>
# 159                                  NaN     <NA>
# 181  Number of Sprinklers Operating: 1.0     <NA>
# 276                                  NaN     <NA>
# 52                                   NaN     <NA>
# 103                                  NaN     <NA>
# 360                                  NaN     <NA>

# %% [markdown]
# For each column after the address/location data, concatenate them into a `_desc` column that has everything in one cell.
#
# This is a temp solution to render all the data in Unity easily.

# %%
# #start row 16
import re
# fires_in_tempe.iloc[:,16:] = fires_in_tempe.iloc[:,16:].astype(str)
# fires_in_tempe['_desc'] = fires_in_tempe.apply(lambda row: '\n'.join(row[16:].fillna('')), axis=1)
fires_in_tempe['_desc'] = fires_in_tempe.apply(lambda row: '\n'.join(row[16:].map(lambda val: '' if pd.isna(val) else str(val))), axis=1)
fires_in_tempe['_desc'] = fires_in_tempe['_desc'].map(lambda val: re.sub(r'\n+', '\n', val))
fires_in_tempe['_desc'] = fires_in_tempe['_desc'].map(lambda val: val.strip('\n'))

# %% [markdown]
# Move `_desc` to front of the table

# %%
cols = fires_in_tempe.columns.tolist()
cols.insert(2,cols.pop())
fires_in_tempe = fires_in_tempe[cols]

# %% [markdown]
# Sort by date, drop anything that doesn't have an address value, then reindex.

# %%
fires_in_tempe = fires_in_tempe.sort_values('INC_DATE')
fires_in_tempe = fires_in_tempe[fires_in_tempe['_addr'].notna()]
fires_in_tempe.reset_index(inplace=True, drop=True)

# %% [markdown]
# Check data again:

# %%
fires_in_tempe.sample(5)
# Out:
#                     INCIDENT_KEY                             _addr  \
# 194  AZ_08293_10252023_2328166_0   1028 E ORANGE ST Tempe AZ 85281
# 64   AZ_08293_05032023_2311214_0  999 E BASELINE RD Tempe AZ 85283
# 82   AZ_08293_05302023_2313827_0  2304 E RANDALL DR Tempe AZ 85281
# 140  AZ_08293_08082023_2320699_0     200 E CURRY RD Tempe AZ 85281
# 47    AZ_08293_04142023_239358_0      58 S RIVER DR Tempe AZ 85281
#
#                                                  _desc STATE   FDID  \
# 194  Area of Origin: Engine area, running gear, whe...    AZ  08293
# 64   Number of Residential Units: 1.0\nNumber of Bu...    AZ  08293
# 82   Number of Residential Units: 2.0\nArea of Orig...    AZ  08293
# 140  Number of Residential Units: 0.0\nNot Resident...    AZ  08293
# 47   Area of Origin: Undetermined\nHeat Source: Und...    AZ  08293
#
#       INC_DATE   INC_NO  EXP_NO  LOC_TYPE NUM_MILE STREET_PRE STREETNAME  \
# 194 2023-10-25  2328166       0         1     1028          E     ORANGE
# 64  2023-05-03  2311214       0         1      999          E   BASELINE
# 82  2023-05-30  2313827       0         1     2304          E    RANDALL
# 140 2023-08-08  2320699       0         1      200          E      CURRY
# 47  2023-04-14   239358       0         1       58          S      RIVER
#
#     STREETTYPE   CITY STATE_ID   ZIP5    X_STREET  \
# 194         ST  Tempe       AZ  85281        <NA>
# 64          RD  Tempe       AZ  85283        <NA>
# 82          DR  Tempe       AZ  85281        <NA>
# 140         RD  Tempe       AZ  85281        <NA>
# 47          DR  Tempe       AZ  85281  S RIVER DR
#
#                              NUM_UNIT                  NOT_RES  \
# 194                               NaN                     <NA>
# 64   Number of Residential Units: 1.0                     <NA>
# 82   Number of Residential Units: 2.0                     <NA>
# 140  Number of Residential Units: 0.0  Not Residential Flag: Y
# 47                                NaN                     <NA>
#
#                             BLDG_INVOL         ACRES_BURN  \
# 194                                NaN                NaN
# 64   Number of Buildings Involved: 1.0                NaN
# 82                                 NaN                NaN
# 140                                NaN  Acres Burned: 0.0
# 47                                 NaN                NaN
#
#                 LESS_1ACRE ON_SITE_M1 MAT_STOR1  ON_SITE_M2  MAT_STOR2  \
# 194                   <NA>       <NA>      <NA>        <NA>       <NA>
# 64   Less Than One Acre: Y       <NA>      <NA>        <NA>       <NA>
# 82                    <NA>       <NA>      <NA>        <NA>       <NA>
# 140                   <NA>       <NA>      <NA>        <NA>       <NA>
# 47                    <NA>       <NA>      <NA>        <NA>       <NA>
#
#      ON_SITE_M3  MAT_STOR3                                          AREA_ORIG  \
# 194        <NA>       <NA>  Area of Origin: Engine area, running gear, whe...
# 64         <NA>       <NA>  Area of Origin: Exterior balcony, unenclosed p...
# 82         <NA>       <NA>   Area of Origin: Courtyard, patio, porch, terrace
# 140        <NA>       <NA>                Area of Origin: Outside area, other
# 47         <NA>       <NA>                       Area of Origin: Undetermined
#
#                           HEAT_SOURC  \
# 194        Heat Source: Undetermined
# 64         Heat Source: Undetermined
# 82   Heat Source: Heat source: other
# 140        Heat Source: Undetermined
# 47         Heat Source: Undetermined
#
#                                            FIRST_IGN  \
# 194                 Item First Ignited: Undetermined
# 64                  Item First Ignited: Undetermined
# 82   Item First Ignited: Appliance housing or casing
# 140                 Item First Ignited: Undetermined
# 47                  Item First Ignited: Undetermined
#
#                                              CONF_ORIG  \
# 194                                               <NA>
# 64                                                <NA>
# 82                                                <NA>
# 140  Confined To Origin: Fire Spread was Confined t...
# 47                                                <NA>
#
#                            TYPE_MAT  \
# 194                            <NA>
# 64   Type of Material: Undetermined
# 82         Type of Material: LP gas
# 140  Type of Material: Undetermined
# 47                             <NA>
#
#                                              CAUSE_IGN  \
# 194                   Cause of Ignition: Unintentional
# 64   Cause of Ignition: Cause undetermined after in...
# 82   Cause of Ignition: Failure of equipment or hea...
# 140       Cause of Ignition: Cause under investigation
# 47                    Cause of Ignition: Unintentional
#
#                                             FACT_IGN_1 FACT_IGN_2 HUM_FAC_1  \
# 194  Factors Contributing To Ignition #1: Undetermined       <NA>      <NA>
# 64   Factors Contributing To Ignition #1: Undetermined       <NA>      <NA>
# 82   Factors Contributing To Ignition #1: Heat sour...       <NA>      <NA>
# 140  Factors Contributing To Ignition #1: Undetermined       <NA>      <NA>
# 47   Factors Contributing To Ignition #1: Undetermined       <NA>      <NA>
#
#     HUM_FAC_2                                          HUM_FAC_3 HUM_FAC_4  \
# 194      <NA>                                               <NA>      <NA>
# 64       <NA>                                               <NA>      <NA>
# 82       <NA>  Human Factors #3: Unattended or unsupervised p...      <NA>
# 140      <NA>                                               <NA>      <NA>
# 47       <NA>                                               <NA>      <NA>
#
#      HUM_FAC_5 HUM_FAC_6 HUM_FAC_7  HUM_FAC_8  AGE  SEX  \
# 194       <NA>      <NA>      <NA>       <NA>  NaN  NaN
# 64        <NA>      <NA>      <NA>       <NA>  NaN  NaN
# 82        <NA>      <NA>      <NA>       <NA>  NaN  NaN
# 140       <NA>      <NA>      <NA>       <NA>  NaN  NaN
# 47        <NA>      <NA>      <NA>       <NA>  NaN  NaN
#
#                             EQUIP_INV SUP_FAC_1  SUP_FAC_2  SUP_FAC_3  \
# 194                              <NA>      <NA>       <NA>       <NA>
# 64   Equipment Involved: Undetermined      <NA>       <NA>       <NA>
# 82                               <NA>      <NA>       <NA>       <NA>
# 140                              <NA>      <NA>       <NA>       <NA>
# 47                               <NA>      <NA>       <NA>       <NA>
#
#                                    FIRE_SPRD  \
# 194                                     <NA>
# 64   Fire Spread: Confined to room of origin
# 82                                      <NA>
# 140                                     <NA>
# 47                                      <NA>
#
#                             STRUC_TYPE                       STRUC_STAT  \
# 194                               <NA>                             <NA>
# 64   Structure Type: Enclosed building  Structure Status: In normal use
# 82                                <NA>                             <NA>
# 140                               <NA>                             <NA>
# 47                                <NA>                             <NA>
#
#                                     BLDG_ABOVE  \
# 194                                        NaN
# 64   Building Height: Stories Above Grade: 4.0
# 82                                         NaN
# 140                                        NaN
# 47                                         NaN
#
#                                     BLDG_BELOW BLDG_LGTH BLDG_WIDTH  \
# 194                                        NaN       NaN        NaN
# 64   Building Height: Stories Below Grade: 0.0       NaN        NaN
# 82                                         NaN       NaN        NaN
# 140                                        NaN       NaN        NaN
# 47                                         NaN       NaN        NaN
#
#                     TOT_SQ_FT                          FIRE_ORIG ITEM_SPRD  \
# 194                       NaN                                NaN      <NA>
# 64   Total Square Feet: 593.0  Fire Origin (starting story): 3.0      <NA>
# 82                        NaN                                NaN      <NA>
# 140                       NaN                                NaN      <NA>
# 47                        NaN                                NaN      <NA>
#
#     MAT_SPRD                              DETECTOR              DET_TYPE  \
# 194     <NA>                                  <NA>                  <NA>
# 64      <NA>  Detector Presence: Detectors Present  Detector Type: Smoke
# 82      <NA>                                  <NA>                  <NA>
# 140     <NA>                                  <NA>                  <NA>
# 47      <NA>                                  <NA>                  <NA>
#
#                                  DET_POWER  \
# 194                                   <NA>
# 64   Detector Power: Hardwire with battery
# 82                                    <NA>
# 140                                   <NA>
# 47                                    <NA>
#
#                                         DET_OPERAT DET_EFFECT DET_FAIL  \
# 194                                           <NA>       <NA>     <NA>
# 64   Detector Operation: Fire too small to operate       <NA>     <NA>
# 82                                            <NA>       <NA>     <NA>
# 140                                           <NA>       <NA>     <NA>
# 47                                            <NA>       <NA>     <NA>
#
#                        AES_PRES AES_TYPE AES_OPER NO_SPR_OP AES_FAIL
# 194                        <NA>     <NA>     <NA>       NaN     <NA>
# 64   AES Presence: None Present     <NA>     <NA>       NaN     <NA>
# 82                         <NA>     <NA>     <NA>       NaN     <NA>
# 140                        <NA>     <NA>     <NA>       NaN     <NA>
# 47                         <NA>     <NA>     <NA>       NaN     <NA>

# %% [markdown]
# Export the ID, address, description, and incident date to CSV for part 2.

# %%
fires_in_tempe[['INCIDENT_KEY','_addr','_desc','INC_DATE']].to_csv(out_file_path, index=False)
